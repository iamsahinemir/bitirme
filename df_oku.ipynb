# %%
import pandas as pd

# Satır limitini kaldır
pd.set_option('display.max_rows', None)

# CSV’yi oku
df = pd.read_csv("Chatbot_Sorular_Varyantlar_DoğruCevaplu.csv", encoding="utf-8")

# DataFrame’i ekrana bas (ya da sadece df yazarak da görüntüleyebilirsin)
df
# Out:
#      Soru No                                               Soru  \
# 0          1  Makinenin en fazla arıza yaptığı tarih aralığı...
# 1          1  Makinenin en fazla arıza yaptığı tarih aralığı...
# 2          1  Makinenin en fazla arıza yaptığı tarih aralığı...
# 3          1  Makinenin en fazla arıza yaptığı tarih aralığı...
# 4          1  Makinenin en fazla arıza yaptığı tarih aralığı...
# 5          2  Geçmişte sarı alarm seviyesinde en çok hangi t...
# 6          2  Geçmişte sarı alarm seviyesinde en çok hangi t...
# 7          2  Geçmişte sarı alarm seviyesinde en çok hangi t...
# 8          2  Geçmişte sarı alarm seviyesinde en çok hangi t...
# 9          2  Geçmişte sarı alarm seviyesinde en çok hangi t...
# 10         3  Geçmişte kırmızı alarm seviyesinde en çok hang...
# 11         3  Geçmişte kırmızı alarm seviyesinde en çok hang...
# 12         3  Geçmişte kırmızı alarm seviyesinde en çok hang...
# 13         3  Geçmişte kırmızı alarm seviyesinde en çok hang...
# ...

# %%
import pandas as pd

# Satır limitini kaldır
pd.set_option('display.max_rows', None)

# CSV’yi oku
df = pd.read_csv("vibration_df.csv", encoding="utf-8")

# DataFrame’i ekrana bas (ya da sadece df yazarak da görüntüleyebilirsin)
df
